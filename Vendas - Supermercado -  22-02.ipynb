# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
import numpy as np 
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import cufflinks as cf
init_notebook_mode(connected=True)
cf.go_offline()
# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
df = pd.read_csv('supermarket_sales - Sheet1.csv')
df.head(10)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
# 5  699-14-3026      C  Naypyitaw        Normal    Male
# 6  355-53-5943      A     Yangon        Member  Female
# 7  315-22-5665      C  Naypyitaw        Normal  Female
# 8  665-32-9167      A     Yangon        Member  Female
# 9  692-92-5582      B   Mandalay        Member  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
df['Branch'].value_counts().iplot(kind='bar')
# Out:
# <div>
#
#
#             <div id="9e78150e-961a-4670-a6f8-07c6c2bc3c6c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("9e78150e-961a-4670-a6f8-07c6c2bc3c6c")) {
#                     Plotly.newPlot(
#                         '9e78150e-961a-4670-a6f8-07c6c2bc3c6c',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "Branch", "orientation": "v", "text": "", "type": "bar", "x": ["A", "B", "C"], "y": [340, 332, 328]}],
# ...

# %%
df['City'].value_counts().iplot(kind='bar')
# Out:
# <div>
#
#
#             <div id="71ea8180-bb77-492b-b537-676b7dce6a7c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("71ea8180-bb77-492b-b537-676b7dce6a7c")) {
#                     Plotly.newPlot(
#                         '71ea8180-bb77-492b-b537-676b7dce6a7c',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "City", "orientation": "v", "text": "", "type": "bar", "x": ["Yangon", "Mandalay", "Naypyitaw"], "y": [340, 332, 328]}],
# ...

# %%
df.head(3)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total      Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715  1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200  3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255  3/3/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29         Cash   76.40                 4.761905        3.8200     9.6
# 2  13:23  Credit card  324.31                 4.761905       16.2155     7.4

# %%
df['Customer type'].value_counts().iplot(kind='bar')
# Out:
# <div>
#
#
#             <div id="86b4c5cd-4bce-4214-b3d1-86458c945f10" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("86b4c5cd-4bce-4214-b3d1-86458c945f10")) {
#                     Plotly.newPlot(
#                         '86b4c5cd-4bce-4214-b3d1-86458c945f10',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "Customer type", "orientation": "v", "text": "", "type": "bar", "x": ["Member", "Normal"], "y": [501, 499]}],
# ...

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(9,5))
sns.countplot(x='City', hue='Customer type', data=df)

# %%
df.groupby('City').mean()
# Out:
#            Unit price  Quantity     Tax 5%       Total        cogs  \
# City
# Mandalay    55.659277  5.481928  15.232024  319.872506  304.640482
# Naypyitaw   56.609024  5.582317  16.052367  337.099715  321.047348
# Yangon      54.780853  5.467647  14.874001  312.354031  297.480029
#
#            gross margin percentage  gross income    Rating
# City
# Mandalay                  4.761905     15.232024  6.818072
# Naypyitaw                 4.761905     16.052367  7.072866
# Yangon                    4.761905     14.874001  7.027059

# %%
df.groupby('City').mean().iplot(kind='bar')
# Out:
# <div>
#
#
#             <div id="00c9cd89-a99d-45b7-b97b-efc15a4bb0dd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("00c9cd89-a99d-45b7-b97b-efc15a4bb0dd")) {
#                     Plotly.newPlot(
#                         '00c9cd89-a99d-45b7-b97b-efc15a4bb0dd',
# ...

# %%
df.groupby('Customer type').mean()
# Out:
#                Unit price  Quantity     Tax 5%       Total        cogs  \
# Customer type
# Member          56.206986  5.558882  15.609110  327.791305  312.182196
# Normal          55.135130  5.460922  15.148707  318.122856  302.974148
#
#                gross margin percentage  gross income    Rating
# Customer type
# Member                        4.761905     15.609110  6.940319
# Normal                        4.761905     15.148707  7.005210

# %%
df['Time'].value_counts()
# Out:
# 19:48    7
# 14:42    7
# 17:38    6
# 19:20    5
# 17:16    5
#         ..
# 18:05    1
# 19:12    1
# 11:34    1
# 20:30    1
# 15:09    1
# Name: Time, Length: 506, dtype: int64

# %%
df['Hour'] = df['Time'].apply(lambda Time: Time.split(':')[0])

# %%
df['Hour'].value_counts().iplot(kind='bar')
# Out:
# <div>
#
#
#             <div id="541ec422-703c-4df4-84cf-00f93ee6fdac" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("541ec422-703c-4df4-84cf-00f93ee6fdac")) {
#                     Plotly.newPlot(
#                         '541ec422-703c-4df4-84cf-00f93ee6fdac',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "Hour", "orientation": "v", "text": "", "type": "bar", "x": ["19", "13", "15", "10", "18", "11", "12", "14", "16", "20", "17"], "y": [113, 103, 102, 101, 93, 90, 89, 83, 77, 75, 74]}],
# ...

# %%
df.head(2)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total      Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715  1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200  3/8/2019
#
#     Time  Payment    cogs  gross margin percentage  gross income  Rating Hour
# 0  13:08  Ewallet  522.83                 4.761905       26.1415     9.1   13
# 1  10:29     Cash   76.40                 4.761905        3.8200     9.6   10

# %%
df['Product line'].value_counts().iplot(kind='bar')
# Out:
# <div>
#
#
#             <div id="9c94d6a2-3b5a-4da5-a775-910d31b31921" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("9c94d6a2-3b5a-4da5-a775-910d31b31921")) {
#                     Plotly.newPlot(
#                         '9c94d6a2-3b5a-4da5-a775-910d31b31921',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "Product line", "orientation": "v", "text": "", "type": "bar", "x": ["Fashion accessories", "Food and beverages", "Electronic accessories", "Sports and travel", "Home and lifestyle", "Health and beauty"], "y": [178, 174, 170, 166, 160, 152]}],
# ...

# %%
plt.figure(figsize=(12,8))
sns.countplot(x='Product line', hue='City', data=df)

# %%
df['Month'] = df['Date'].apply(lambda Time: Time.split('/')[0])

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df['Day'] = df['Date'].apply(lambda Time: Time.split('/')[1])

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df['Month'].value_counts()
# Out:
# 1    352
# 3    345
# 2    303
# Name: Month, dtype: int64

# %%
sns.set_style('darkgrid')
sns.distplot(df['Day'], kde=False)

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df['Quantity'].value_counts()
# Out:
# 10    119
# 1     112
# 4     109
# 7     102
# 5     102
# 6      98
# 9      92
# 2      91
# 3      90
# 8      85
# Name: Quantity, dtype: int64

# %%
sns.set_style('darkgrid')
df.hist(column='Quantity', by='Product line', figsize=(9,6), color = 'red')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4cf5a1011610> in <module>
# ----> 1 sns.set_style('darkgrid')
#       2 df.hist(column='Quantity', by='Product line', figsize=(9,6), color = 'red')
#
# NameError: name 'sns' is not defined

# %%
plt.figure(figsize=(12,8))
sns.countplot(x='Quantity', hue='Product line', data=df)

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df[df['City']=='Naypyitaw'].groupby('Product line').mean().iplot(kind='bar')
# Out:
# <div>
#
#
#             <div id="4aaff8b4-f305-4ec5-bdcd-f2de03dfe8e5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("4aaff8b4-f305-4ec5-bdcd-f2de03dfe8e5")) {
#                     Plotly.newPlot(
#                         '4aaff8b4-f305-4ec5-bdcd-f2de03dfe8e5',
# ...

# %%
plt.figure(figsize=(12,8))
sns.set_style('darkgrid')
sns.countplot(x='Product line', hue='Gender', data=df)

# %%
df.groupby('Gender').mean()
# Out:
#         Unit price  Quantity     Tax 5%       Total        cogs  \
# Gender
# Female   55.263952  5.726547  15.956936  335.095659  319.138723
# Male     56.081944  5.292585  14.799487  310.789226  295.989739
#
#         gross margin percentage  gross income    Rating
# Gender
# Female                 4.761905     15.956936  6.964471
# Male                   4.761905     14.799487  6.980962

# %%
df[df['Gender']=='Male'].groupby('Product line').mean()
# Out:
#                         Unit price  Quantity     Tax 5%       Total  \
# Product line
# Electronic accessories   55.016744  5.616279  15.080570  316.691965
# Fashion accessories      59.058049  4.536585  13.860915  291.079207
# Food and beverages       51.635833  5.214286  13.023768  273.499125
# Health and beauty        57.592841  5.806818  16.576165  348.099460
# Home and lifestyle       53.438889  5.098765  14.006488  294.136241
# Sports and travel        59.955897  5.435897  16.207635  340.360327
#
#                               cogs  gross margin percentage  gross income  \
# Product line
# Electronic accessories  301.611395                 4.761905     15.080570
# Fashion accessories     277.218293                 4.761905     13.860915
# Food and beverages      260.475357                 4.761905     13.023768
# Health and beauty       331.523295                 4.761905     16.576165
# Home and lifestyle      280.129753                 4.761905     14.006488
# ...

# %%
df[df['Gender']=='Male'].groupby('Product line').mean().plot(kind='bar', figsize=(12,8))

# %%
df[df['Gender']=='Female'].groupby('Product line').mean()
# Out:
#                         Unit price  Quantity     Tax 5%       Total  \
# Product line
# Electronic accessories   52.051548  5.809524  15.363958  322.643125
# Fashion accessories      55.526979  5.520833  15.097917  317.056250
# Food and beverages       60.090333  5.711111  17.550750  368.565750
# Health and beauty        51.089219  5.359375  13.810258  290.015414
# Home and lifestyle       57.242532  6.303797  18.105411  380.213639
# Sports and travel        54.367273  5.636364  15.462511  324.712739
#
#                               cogs  gross margin percentage  gross income  \
# Product line
# Electronic accessories  307.279167                 4.761905     15.363958
# Fashion accessories     301.958333                 4.761905     15.097917
# Food and beverages      351.015000                 4.761905     17.550750
# Health and beauty       276.205156                 4.761905     13.810258
# Home and lifestyle      362.108228                 4.761905     18.105411
# ...

# %%
df[df['Gender']=='Female'].groupby('Product line').mean().plot(kind='bar', figsize=(12,8))

# %%
df.head(2)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total      Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715  1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200  3/8/2019
#
#     Time  Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08  Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29     Cash   76.40                 4.761905        3.8200     9.6

# %%
df.groupby('Payment').mean()
# Out:
#              Unit price  Quantity     Tax 5%       Total        cogs  \
# Payment
# Cash          56.758983  5.511628  15.532471  326.181890  310.649419
# Credit card   54.394469  5.536977  15.429042  324.009878  308.580836
# Ewallet       55.740174  5.484058  15.181933  318.820600  303.638667
#
#              gross margin percentage  gross income    Rating
# Payment
# Cash                        4.761905     15.532471  6.970058
# Credit card                 4.761905     15.429042  7.003215
# Ewallet                     4.761905     15.181933  6.947826

# %%
plt.figure(figsize=(12,8))
sns.countplot(x='Product line', hue='Payment', data=df)

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
sns.lmplot(x = 'cogs', y='Rating', data=df)

# %%
sns.lmplot(x = 'Quantity', y='Rating', data=df)

# %%
sns.lmplot(x = 'Unit price', y='Rating', data=df)

# %%
sns.pairplot(df)
